# %%
# Let's create an empty list
my_list = []
print(my_list)
# Out:
# []

# %%
#Let's add some values
my_list = ('Python')
my_list = ('is ok')
my_list = ('sometimes')

print (my_list)
# Out:
# sometimes

# %%
# Let's remove 'sometimes'
my_list = ['Python ', 'is ok ', 'sometimes']
print (my_list)
my_list.remove('sometimes');
print (my_list)
# Out:
# ['Python ', 'is ok ', 'sometimes']
# ['Python ', 'is ok ']

# %%
# Let's change the second item to 'is neat'
my_list = ['Python ', 'is ok']
type(my_list)
print (my_list)
my_list.replace('is ok', '');
print (my_list)

# %%
# Let's verify that it's correct
my_list = ['Python','is neat']
assert my_list == ['Python', 'is neat']
#print (my_list)
#type (my_list)

# %%
# Let's verify that it's false
my_list = ['Python','is neat']
assert my_list == ['Python', 'is cool']
#print (my_list)
#type (my_list)
# Out:
# AssertionErrorTraceback (most recent call last)
# <ipython-input-64-9289afd618f9> in <module>()
#       1 my_list = ['Python','is neat']
# ----> 2 assert my_list == ['Python', 'is cool']
#       3 #print (my_list)
#       4 #type (my_list)
#
# AssertionError:

# %%
#2. Create a new list without modifiying the original one
original = ['I', 'am', 'learning', 'hacking', 'in']
#type(original)
modified = [original.extend(['Python'])]
type(modified)
print(modified)
# Out:
# [None]

# %%
#2. Create a new list without modifiying the original one
original = ['I', 'am', 'learning', 'hacking', 'in']
assert original == ['I', 'am', 'learning', 'hacking', 'in']
type(original)
original.extend(['Python'])
print(original)
assert original == ['I', 'am', 'learning', 'hacking', 'in', 'Python']
# Out:
# ['I', 'am', 'learning', 'hacking', 'in', 'Python']

# %%
#3. Create a merged sorted list

list1 = [6, 12, 5]
list2 = [6.2, 0, 14, 1]
list3 = [0.9]
# printing original lists  
print ("The original list 1 is : " + str(list1)) 
print ("The original list 2 is : " + str(list2)) 
print ("The original list 3 is : " + str(list3)) 
my_list = sorted(list1 + list2 + list3) 
print ("The combined sorted list is : " + str(my_list)) 
#assert my_list == [14, 12, 6.2, 6, 5, 1, 0.9, 0]
#sorted(my_list, key=str, reverse=True)
print sorted(my_list)
my_list.sort(reverse=True)
print(my_list)
assert my_list == [14, 12, 6.2, 6, 5, 1, 0.9, 0]
# Out:
# The original list 1 is : [6, 12, 5]
# The original list 2 is : [6.2, 0, 14, 1]
# The original list 3 is : [0.9]
# The combined sorted list is : [0, 0.9, 1, 5, 6, 6.2, 12, 14]
# [0, 0.9, 1, 5, 6, 6.2, 12, 14]
# [14, 12, 6.2, 6, 5, 1, 0.9, 0]

# %%
print("isinstance(lst_inst, list) = " ,isinstance(lst_inst, list))

# %%
loop_list1 = [1101, 704.971, 'Fort Mill']
for x in range(len(loop_list1)):
  print(x)
  if isinstance(loop_list1[x],float):
    loop_list1[x] = int (loop_list1[x])
  elif isinstance(loop_list1[x],int):
	   loop_list1[x] = float (loop_list1[x])
print(loop_list1)
assert loop_list1 == [1101.0, 704, 'Fort Mill']
# Out:
# 0
# 1
# 2
# [1101.0, 704, 'Fort Mill']

# %%
loop_list2 = [1101, 704.971, 'Fort Mill']

while x in range(len(loop_list2)) <=2:
  x =  x in range(len(loop_list2))
  print(x)
  if isinstance(loop_list2[x],float):
    loop_list1[x] = int (loop_list2[x])
  elif isinstance(loop_list2[x],int):
	   loop_list2[x] = float (loop_list2[x])
  x += 1 
print(loop_list2)
assert loop_list2 == [1101, 704, 'Fort Mill']
# Out:
# [1101, 704.971, 'Fort Mill']
# AssertionErrorTraceback (most recent call last)
# <ipython-input-245-a833dd8da93e> in <module>()
#      10   x += 1
#      11 print(loop_list2)
# ---> 12 assert loop_list2 == [1101, 704, 'Fort Mill']
#
# AssertionError:

# %%
# TODO
# create a tuple with items of different data types
#my_tuple = ___
#print(my_tuple, type(my_tuple))


my_tuple = ("my_tuple", False, 3.2, 1)
print(my_tuple, type(my_tuple))
print (my_tuple)
# Out:
# (('my_tuple', False, 3.2, 1), <type 'tuple'>)
# ('my_tuple', False, 3.2, 1)

# %%
# Unpack my_tuple in several variables
my_tuple = ("my_tuple", False, 3.2, 1)

n1, n2, n3, n4 = my_tuple
print(n1) 
print(n2)
print( n3 +  n4)
# Out:
# my_tuple
# False
# 4.2

# %%
# convert my_tuple to list and assign to variable my_list
my_tuple = ("my_tuple", False, 3.2, 1)
print(my_tuple)
list(my_tuple)
# Out:
# ('my_tuple', False, 3.2, 1)
# ['my_tuple', False, 3.2, 1]

# %%
# convert my_list to tuple and assign to variable my_new_tuple
>>> my_list = [1101, 704.971, 'Fort Mill']
>>> my_list
>>> tuple(my_list)
# Out:
# (1101, 704.971, 'Fort Mill')

# %%
# TODO
rv_tuple = 1101, 'Red', 'Ventures', 'Drive'
print(rv_tuple, type(rv_tuple))
# check id
print(___(rv_tuple))
# modify the variable
rv_tuple = rv_tuple + (29707, )
print(rv_tuple, type(rv_tuple))
# check id
print(___(rv_tuple))

# TODO
# Do the same exercises as above for a list and see the difference
# Remember list is muttable

# %%
rv_tuple = 1101, 'Red', 'Ventures', 'Drive'
print(rv_tuple, type(rv_tuple))

# %%
# check id
rv_tuple = 1101, 'Red', 'Ventures', 'Drive'
rv_tuple1 = 1101, 'Red', 'Ventures', 'Drive'
rv_tuple is rv_tuple1
# Out:
# False

# %%
# check id
rv_tuple = 1101, 'Red', 'Ventures', 'Drive', 29707 
rv_tuple1 = 1101, 'Red', 'Ventures', 'Drive', 29707
rv_tuple is rv_tuple1
# Out:
# False

# %%
# modify the variable
rv_tuple = rv_tuple + (29707, )
print(rv_tuple, type(rv_tuple))
# Out:
# ((1101, 'Red', 'Ventures', 'Drive', 29707), <type 'tuple'>)

# %%
def check_case(string=raw_input("This is Week3 Python Programming Homework.")):
  string=raw_input("This is Week3 Python Programming Homework.")
  count1=0
  count2=0
  for i in string:
      if(i.islower()):
            count1=count1+1
      elif(i.isupper()):
            count2=count2+1
  print("The number of lowercase characters is:")
  return(count1)
  print(count1)
  print("The number of uppercase characters is:")
  return(count2)
  print(count2)
#assert count1 == 5
#assert count2 == 30

# %%
 return uppercase_number, lowercase_number

# %%
def check_case(s):
    d={"UPPER_CASE":0, "LOWER_CASE":0}
    for c in s:
        if c.isupper():
          d["UPPER_CASE"]+=1
        elif c.islower():
           d["LOWER_CASE"]+=1
        else:
           pass
    print ("Original String : ", s)
    return(d)
    #print ("No. of Upper case characters : ", d["UPPER_CASE"])
    #print ("No. of Lower case Characters : ", d["LOWER_CASE"])

check_case('This is Week3 Python Programming Homework')
#assert count1 == 5
#assert count2 == 30
# Out:
# ('Original String : ', 'This is Week3 Python Programming Homework')
# {'LOWER_CASE': 30, 'UPPER_CASE': 5}

# %%
1. Fill the ___ parts of code below
In [ ]:
# TODO
# create an empty dictionary
my_dict = ___
print(my_dict, type(my_dict))

# create a dictionary with values
my_dict = ___
print(my_dict, type(my_dict))

# add key/value to my_dict
my_dict___
print(my_dict)

# remove the key you added from my_dict
my_dict___
print(my_dict)

# %%
# create an empty dictionary
my_dict = {}
print(my_dict, type(my_dict))
# Out:
# ({}, <type 'dict'>)

# %%
# create a dictionary with values
my_dict = {'k1': "cat", 'k2': "dog", 'k3': "mouse", 'k4': "fish" }
print(my_dict, type(my_dict))
# Out:
# ({'k3': 'mouse', 'k2': 'dog', 'k1': 'cat', 'k4': 'fish'}, <type 'dict'>)

# %%
# add key/value to my_dict
my_dict = {'k1': "cat", 'k2': "dog", 'k3': "mouse", 'k4': "fish" }
my_dict['k5'] = 'parrot'
print(my_dict, type(my_dict))
# Out:
# ({'k3': 'mouse', 'k2': 'dog', 'k1': 'cat', 'k5': 'parrot', 'k4': 'fish'}, <type 'dict'>)

# %%
# add key/value to my_dict
my_dict = {'k1': "cat", 'k2': "dog", 'k3': "mouse", 'k4': "fish", 'k5': "parrot"}
del my_dict['k5']
print(my_dict, type(my_dict))
# Out:
# ({'k3': 'mouse', 'k2': 'dog', 'k1': 'cat', 'k4': 'fish'}, <type 'dict'>)

# %%
#2. Sort Dictionary
#Print out key/value pair by the ascending order of keys.
# TODO
#location_dict = {'Charlotte': 'NC', 'Austin': 'TX', 'New York': 'NY', 'Los Angeles': 'CA'}
location_dict = {'Charlotte': 'NC', 'Austin': 'TX', 'New York': 'NY', 'Los Angeles': 'CA'}
for key in sorted(location_dict):
    print "%s: %s" % (key, location_dict[key])
# Out:
# Austin: TX
# Charlotte: NC
# Los Angeles: CA
# New York: NY

# %%
#Display the location_dict by the desending order of values.
# TODO
#location_dict = {'Charlotte': 'NC', 'Austin': 'TX', 'New York': 'NY', 'Los Angeles': 'CA'}

location_dict = {'Charlotte': 'NC', 'Austin': 'TX', 'New York': 'NY', 'Los Angeles': 'CA'}
for key in sorted(location_dict, reverse=True):
    print "%s: %s" % (key, location_dict[key])
# Out:
# New York: NY
# Los Angeles: CA
# Charlotte: NC
# Austin: TX

# %%
# TODO
# create an set
my_set = ____
print(my_set, type(my_set), '\n')

# create a set with values
my_set = ____
print(my_set, type(my_set), '\n')

# add a new value to my_set
# the value should be a different
my_set.___
print(my_set, '\n')


# remove the value you added from my_set
my_set.____
print(my_set, '\n')

# %%
# create an set
my_set = {"apple"}
print(my_set, type(my_set), '\n')
# Out:
# (set(['apple']), <type 'set'>, '\n')

# %%
# create a set with values
my_set = {"apple", "banana", "cherry"}
print(my_set, type(my_set), '\n')
# Out:
# (set(['cherry', 'apple', 'banana']), <type 'set'>, '\n')

# %%
# add a new value to my_set
# the value should be a different
my_set = {"apple", "banana", "cherry"}
my_set.add("orange")
print(my_set, '\n')
# Out:
# (set(['orange', 'cherry', 'apple', 'banana']), '\n')

# %%
# remove the value you added from my_set
my_set = {"apple", "banana", "cherry", "orange"}
my_set.remove('banana')
print(my_set, '\n')
# Out:
# (set(['orange', 'cherry', 'apple']), '\n')

# %%
#Use a list with duplicated values and a tuple to create two sets respectivley, and get a union set between those two.
set1_list = [0, 2, 4,5, 5, 6, 8];
set2_tuple = (1, 2, 3, 6, 4, 5);
type(set1_list)
type(set2_tuple)
# union 
print(set1_list | set2_tuple)
#print(intersection(lst1, lst2)) 
#print("Union :", set1_list, set1_list) 
#print("intersection :", set1_list & set1_list) 
#print(intersection(set1_list, set2_tuple)) 
#print(intersection(lst1, lst2)) 
#why is the function not working?

#Have some questions on this on why the instersion/union function is not working
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-363-412fa8a0bc96> in <module>()
#       4 type(set2_tuple)
#       5 # union
# ----> 6 print(set1_list | set2_tuple)
#       7 #print(intersection(lst1, lst2))
#       8 #print("Union :", set1_list, set1_list)
#
# TypeError: unsupported operand type(s) for |: 'list' and 'tuple'

# %%
#Create two sets my_set1 and my_set2, and get values in my_set1 but not in my_set2.

set1 = [0, 2, 4,5, 5, 6, 8];
set2 = [1, 2, 3, 6, 4, 5];
#type(set1)
type(set2)
print(intersection(set1, set1) 
# union 
#print(set1_list | set2_tuple)
#print(intersection(lst1, lst2)) 
#print("Union :", set1_list, set1_list) 
#print("intersection :", set1_list & set1_list) 
#print(intersection(set1_list, set2_tuple)) 
#print(intersection(lst1, lst2)) 
#why is the function not working?
   #Have some questions on this on why the instersion/union function is not working
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-371-7a5ebddc9d91> in <module>()
#       3 #type(set1)
#       4 type(set2)
# ----> 5 print(intersection[set1, set1])
#       6 # union
#       7 #print(set1_list | set2_tuple)
#
# NameError: name 'intersection' is not defined
