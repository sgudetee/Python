# %%
x=100
type(x)
# Out:
# int

# %%
print(x)
# Out:
# 100

# %%
x = "Hello World"
type(x)
# Out:
# str

# %%
print(x)
# Out:
# Hello World

# %%
organes
print(oranges)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-eae3461ea479> in <module>()
# ----> 1 organes
#       2 print(oranges)
#
# NameError: name 'organes' is not defined

# %%
# Operator and comparision

# %%
x = 1+2
print (x)
# Out:
# 3

# %%
y = 1-2
print(y)
# Out:
# -1

# %%
j=1*2
print(j)
# Out:
# 2

# %%
k =1/2
print(k)
# Out:
# 0.5

# %%
x1 = 1//2
print(x1)
# Out:
# 0

# %%
i= 10.20/5.01
print (i)
# Out:
# 2.035928143712575

# %%
j1 = 2**15
print(j1)
# Out:
# 32768

# %%
1+2 == 1.0+2
# Out:
# True

# %%
10 == 10
# Out:
# True

# %%
10 !=10
# Out:
# False

# %%
5 <=10
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
 11 = [1, 2]
int 12 = [1, 2.0]
11 is 12
# Out:
#   File "<ipython-input-2-c33470c18bfe>", line 1
#     int 11 = [1, 2]
#          ^
# SyntaxError: invalid syntax

# %%
x1 = 'Welcome '
x2 ="DSC "
x3 = "Homegrown 2019"
print (x1 +x2 +x3)
# Out:
# Welcome DSC Homegrown 2019

# %%
str = "Hello World"
print(len(str))
# Out:
# 11

# %%
chklen = "Hello World!"
print(chklen[0])
# Out:
# H

# %%
getchar = "Hello World!"
print(getchar[0:3])
# Out:
# Hel

# %%
s = "Red Ventures"
print(s[4:5])
# Out:
# V

# %%
s="charlotte"
print(s[len(s)-1])
# Out:
# e

# %%
t='     Everthing is written in pencil.'
print(t)
# Out:
#      Everthing is written in pencil.

# %%
print (' Everthing is written \n in pencil.')
# Out:
#  Everthing is written
#  in pencil.

# %%
print (' Everthing \\ is written \\ in pencil.')
# Out:
#  Everthing \ is written \ in pencil.

# %%
print ('Red Ventures brands, just list a few: \n * Bankrate \n * Reveiws.com \n * the Points Guy \n * Creditcards.com')
# Out:
# Red Ventures brands, just list a few:
#  * Bankrate
#  * Reveiws.com
#  * the Points Guy
#  * Creditcards.com

# %%
s ='RED FISH'
print(s.lower())
# Out:
# red fish

# %%
s='Run Up Escalators'
#s.startswith(r, beg=0,end=len(string));
print(s.startswith( 'r' ))
# Out:
# False

# %%
s = "You dont't have to lie."

x = s.find("You dont't have to lie")

print(x)
# Out:
# 0

# %%
z = "123"
print("Data type of z:",type(z))
z=int(z)
print("Data type of z string after Type Casting:",type(z))
# Out:
# Data type of z: <class 'str'>
# Data type of z string after Type Casting: <class 'int'>

# %%
myint = 1+2
print (myint)
myfloat = 1.0 + 2
print (myfloat)
myint is myfloat
# Out:
# 3
# 3.0
# False

# %%
i = 1+2
f = 1.0 + 2

print("Data type of i:",type(i))
print("Data type of f:",type(f))

if type(i) == type(f) and i == f:
    print("They're equal by value and type!")      
elif type(i) == type(f):
    print("They're equal by type and not value.")
elif i == f:
    print("They're equal by value and not type.")
else:
    print("They aren't equal by value or type.")
# Out:
# Data type of i: <class 'int'>
# Data type of f: <class 'float'>
# They're equal by value and not type.

# %%
num_int = 123
num_str = "456"

num_int = 123
num_str = "456"

print("Data type of num_int:",type(num_int))
print("Data type of num_str before Type Casting:",type(num_str))

num_str = int(num_str)
print("Data type of num_str after Type Casting:",type(num_str))

num_sum = num_int + num_str

print("Sum of num_int and num_str:",num_sum)
print("Data type of the sum:",type(num_sum))
# Out:
# Data type of num_int: <class 'int'>
# Data type of num_str before Type Casting: <class 'str'>
# Data type of num_str after Type Casting: <class 'int'>
# Sum of num_int and num_str: 579
# Data type of the sum: <class 'int'>

# %%
# Returns True as x is -1

# What happends if you cast -1 to a boolean?
x = -1
print("Data type of x:",type(x))
print(bool(x))
# Out:
# Data type of x: <class 'int'>
# True

# %%
#Import math module and calcualte e^4.
import math
int = 4
print(math.exp(int))
# Out:
# 54.598150033144236

# %%
#Calculate the value of log_2(8)
import math
x = 8
# Returns the log2 of 8
print("The log2 of 8 is:", math.log2(x))
# Out:
# The log2 of 8 is: 3.0

# %%
#Calculate the value of sqrt{100}.
import math
x = 81
math.sqrt(x)
# Out:
# 9.0
